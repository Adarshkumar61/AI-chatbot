# %% [markdown]
# <a href="https://colab.research.google.com/github/Adarshkumar61/AI-chatbot/blob/main/Chat_Bot_using_Deep_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DATA

# %%
data = {"intents": [
    {"tag": "greeting",
     "patterns": ["Hi", "Hey", "Is anyone there?", "Hello", "Hay"],
     "responses": ["Hello", "Hi", "Hi there"]
    },
    {
      "tag": "joke",
      "patterns": ["Tell me a joke", "Make me laugh", "Say something funny"],
      "responses": [
        "Why don’t robots ever get tired? Because they recharge!",
        "I told my computer a joke… but it didn’t get it 🤖",
        "Why was the math book sad? Because it had too many problems!"
      ]
    },
    {"tag": "goodbye",
     "patterns": ["Bye", "See you later", "Goodbye"],
     "responses": ["See you later", "Have a nice day", "Bye! Come back again"]
    },
    {"tag": "thanks",
     "patterns": ["Thanks", "Thank you", "That's helpful", "Thanks for the help"],
     "responses": ["Happy to help!", "Any time!", "My pleasure", "You're most welcome!"]
    },
    {
      "tag": "bot_function",
      "patterns": ["What can you do?", "What are your abilities?", "How can you help me?"],
      "responses": ["I can chat with you, answer questions, and make you smile 😄", "I'm here to talk and keep you company!"]
    },
    {
      "tag": "smalltalk_sad",
      "patterns": ["I am sad", "I feel down", "I am not okay", "Life is hard"],
      "responses": ["I’m here for you 💙", "I’m sorry you feel that way.", "Things will get better, stay strong!"]
    },
    {
      "tag": "smalltalk_happy",
      "patterns": ["I am happy", "I feel great", "I am excited", "Today is awesome"],
      "responses": ["That’s wonderful to hear!", "I’m glad you’re feeling good!", "Happiness is the best!"]
    },
    {"tag": "about",
     "patterns": ["Who are you?", "What are you?", "Who you are?" ],
     "responses": ["I.m Joana, your bot assistant", "I'm Joana, an Artificial Intelligent bot"]
    },
    {"tag": "name",
    "patterns": ["what is your name", "what should I call you", "whats your name?"],
    "responses": ["You can call me Joana.", "I'm Joana!", "Just call me as Joana"]
    },
    {"tag": "help",
    "patterns": ["Could you help me?", "give me a hand please", "Can you help?", "What can you do for me?", "I need a support", "I need a help", "support me please"],
    "responses": ["Tell me how can assist you", "Tell me your problem to assist you", "Yes Sure, How can I support you"]
    },
    {"tag": "createaccount",
    "patterns": ["I need to create a new account", "how to open a new account", "I want to create an account", "can you create an account for me", "how to open a new account"],
    "responses": ["You can just easily create a new account from our web site", "Just go to our web site and follow the guidelines to create a new account"]
    },
     {
      "tag": "time",
      "patterns": ["What time is it?", "Can you tell me the time?", "Do you know the time?", "Clock?", "Current time please"],
      "responses": ["I don’t have a watch, but your device clock can help!", "Sorry, I can’t tell exact time."]
    },
    {
      "tag": "date",
      "patterns": ["What’s the date today?", "Tell me today’s date", "What day is it?", "Current date?", "Today’s calendar date?"],
      "responses": ["I can’t track the live date, but your system can.", "Check your device calendar for today’s date."]
    },
    {
      "tag": "country",
      "patterns": ["What is India?", "Tell me about USA", "Do you know Japan?", "Where is France?", "What is Germany known for?"],
      "responses": ["India is known for its diversity.", "USA is a powerful country with many states.", "Japan is famous for technology and anime."]
    },
    {
      "tag": "sports",
      "patterns": ["Who won the world cup?", "Tell me about football", "Do you know cricket?", "What is basketball?", "Who is Messi?"],
      "responses": ["Cricket is a famous sport in Asia.", "Football is loved worldwide.", "Messi is one of the greatest footballers."]
    },
    {
      "tag": "food",
      "patterns": ["What’s your favorite food?", "Do you eat pizza?", "Tell me about burgers", "What is biryani?", "Do you know samosa?"],
      "responses": ["Pizza is loved worldwide.", "Biryani is a delicious Indian dish.", "Samosa is a popular snack in India."]
    },
    {
      "tag": "hobby",
      "patterns": ["What are your hobbies?", "Do you play games?", "Do you like reading?", "Tell me your hobby", "What do you enjoy?"],
      "responses": ["I love chatting with you!", "I enjoy helping people learn.", "My hobby is processing data."]
    },
    {
      "tag": "motivation",
      "patterns": ["Motivate me", "Say something positive", "Give me motivation", "Inspire me", "I feel low"],
      "responses": ["Believe in yourself!", "You can achieve anything!", "Keep going, success is near."]
    },
    {
      "tag": "study",
      "patterns": ["Help me study", "How to focus?", "How can I prepare for exams?", "Tips for learning", "How to avoid distractions?"],
      "responses": ["Study in short intervals.", "Avoid distractions like phones.", "Make notes and revise daily."]
    },
    {
      "tag": "technology",
      "patterns": ["What is AI?", "Explain machine learning", "What is deep learning?", "Tell me about Python", "Do you know TensorFlow?"],
      "responses": ["AI is Artificial Intelligence.", "Machine learning helps machines learn from data.", "Deep learning uses neural networks for complex problems."]
    },
    {
      "tag": "robot_teacher",
      "patterns": ["Are you my teacher?", "Can you teach me?", "Explain like a teacher", "Can you guide me?", "Are you my mentor?"],
      "responses": ["Yes, I can be your teacher!", "I’ll guide you step by step.", "Think of me as your digital mentor."]
    },
    {
      "tag": "movies",
      "patterns": ["Recommend me a movie", "Best movies to watch", "Tell me a good film", "What movie should I watch?", "Suggest a film"],
      "responses": ["You should watch Inception.", "Try Interstellar.", "Avengers is always fun.", "How about The Dark Knight?", "Parasite is really good."]
    },
    {
      "tag": "music",
      "patterns": ["Play some music", "Recommend me a song", "What should I listen to?", "Best songs?", "Tell me a good track"],
      "responses": ["How about some classical music?", "Try listening to Imagine Dragons.", "You might like Ed Sheeran.", "Listen to some relaxing lo-fi.", "Taylor Swift has some great songs."]
    },

    {"tag": "complaint",
    "patterns": ["have a complaint", "I want to raise a complaint", "there is a complaint about a service"],
    "responses": ["Please provide us your complaint in order to assist you", "Please mention your complaint, we will reach you and sorry for any inconvenience caused"]
    },
       {
      "tag": "weather_info",
      "patterns": ["What's the weather?", "Tell me today's weather", "Weather update", "Is it raining?", "How hot is it outside?"],
      "responses": ["It looks sunny today!", "Expect some clouds today.", "Might be rainy, carry an umbrella!", "It’s quite hot today.", "Cool and pleasant weather today!"]
    },
    {
      "tag": "time_info",
      "patterns": ["What time is it?", "Tell me the current time", "Do you know the time?", "Can you give me the time?", "What's the time now?"],
      "responses": ["It’s time to shine 🌞", "Here’s the current time on your system!", "You can check your device clock for exact time.", "It’s ticking fast!", "Time waits for none."]
    },
    {
      "tag": "date_info",
      "patterns": ["What's today's date?", "Tell me the date", "Which day is it?", "Give me the date please", "Do you know what day it is?"],
      "responses": ["Today is a great day!", "It’s [system date].", "Check your device calendar for today’s date.", "It’s a beautiful day.", "Another fresh day ahead!"]
    },
    {
      "tag": "motivation",
      "patterns": ["Motivate me", "Say something inspiring", "Give me motivation", "I need encouragement", "Cheer me up"],
      "responses": ["Believe in yourself!", "You’re stronger than you think.", "Keep pushing forward!", "Success starts with the first step.", "Don’t give up!"]
    },
    {
      "tag": "math_addition",
      "patterns": ["What is 2 plus 2?", "Add 5 and 6", "Sum of 10 and 20", "Can you add numbers?", "What's 100+200?"],
      "responses": ["2+2=4", "5+6=11", "10+20=30", "100+200=300", "Sure, I can add numbers for you!"]
    },
    {
      "tag": "math_subtraction",
      "patterns": ["What is 10 minus 3?", "Subtract 7 from 20", "Difference between 15 and 5", "Can you do subtraction?", "50-25"],
      "responses": ["10-3=7", "20-7=13", "15-5=10", "50-25=25", "Yes, I can subtract numbers too!"]
    },
    {
      "tag": "math_multiplication",
      "patterns": ["Multiply 3 and 4", "What is 7 times 8?", "Can you do multiplication?", "Calculate 9*9", "Product of 12 and 5"],
      "responses": ["3×4=12", "7×8=56", "9×9=81", "12×5=60", "Multiplication is easy for me!"]
    },
    {
      "tag": "math_division",
      "patterns": ["What is 20 divided by 5?", "Divide 100 by 10", "Can you do division?", "50/2", "Find quotient of 90 and 9"],
      "responses": ["20÷5=4", "100÷10=10", "50÷2=25", "90÷9=10", "Yes, I can divide numbers too!"]
    },
    {
      "tag": "currency_conversion",
      "patterns": ["Convert 10 dollars to rupees", "How much is 50 euros in INR?", "Currency conversion", "Exchange rate please", "USD to INR"],
      "responses": ["10 USD ≈ 830 INR", "50 EUR ≈ 4500 INR", "Conversion depends on current exchange rate.", "I can help with currency estimates!", "Check live forex rates for accuracy."]
    },
    {
      "tag": "philosophy",
      "patterns": ["What is the meaning of life?", "Why are we here?", "What is happiness?", "What is consciousness?", "Why do we exist?"],
      "responses": ["Philosophers have debated that for centuries. Some say the meaning of life is to seek knowledge and happiness.", "It may depend on personal beliefs, but many find purpose in relationships, creativity, and growth.", "Consciousness remains one of the biggest mysteries in science and philosophy."]
    },
    {
      "tag": "history_india",
      "patterns": ["Who was Ashoka?", "Tell me about Akbar", "Who was the first Prime Minister of India?", "What is the Mughal Empire?", "Who was Chandragupta Maurya?"],
      "responses": ["Ashoka was an Indian emperor of the Maurya Dynasty.", "Akbar was one of the greatest Mughal emperors.", "Jawaharlal Nehru was the first Prime Minister of India.", "The Mughal Empire ruled large parts of India from the 16th to 19th centuries.", "Chandragupta Maurya founded the Maurya Empire in ancient India."]
    },
    {
      "tag": "geography",
      "patterns": ["What is the capital of France?", "Which is the largest ocean?", "Where is Mount Everest?", "Which is the smallest country?", "What is the capital of Japan?"],
      "responses": ["The capital of France is Paris.", "The Pacific Ocean is the largest.", "Mount Everest is located on the border of Nepal and China.", "Vatican City is the smallest country.", "The capital of Japan is Tokyo."]
    },
    {
      "tag": "science_space",
      "patterns": ["What is a black hole?", "How far is the moon?", "What is the Milky Way?", "What is a galaxy?", "What is the speed of light?"],
      "responses": ["A black hole is a region in space where gravity is so strong that nothing can escape.", "The moon is about 384,000 km away from Earth.", "The Milky Way is the galaxy that contains our Solar System.", "A galaxy is a huge collection of stars, gas, and dust bound together by gravity.", "The speed of light is approximately 299,792 km per second."]
    },
    {
      "tag": "computer_basics",
      "patterns": ["What is a CPU?", "What is RAM?", "What is an operating system?", "What is a hard disk?", "What is the internet?"],
      "responses": ["CPU stands for Central Processing Unit, the brain of a computer.", "RAM is Random Access Memory, used for temporary storage.", "An operating system is software that manages computer hardware and software resources.", "A hard disk is storage used to save files and programs.", "The internet is a global network that connects millions of computers."]
    },
    {
      "tag": "sports_cricket",
      "patterns": ["Who is Virat Kohli?", "How many players in a cricket team?", "What is an over?", "Who won the 2011 World Cup?", "What is LBW in cricket?"],
      "responses": ["Virat Kohli is an Indian cricketer and former captain.", "A cricket team has 11 players.", "An over consists of 6 balls.", "India won the 2011 Cricket World Cup.", "LBW stands for Leg Before Wicket, a way of getting out in cricket."]
    },
    {
      "tag": "sports_football",
      "patterns": ["Who is Lionel Messi?", "What is the World Cup?", "How many players in a football team?", "Who is Cristiano Ronaldo?", "Which country invented football?"],
      "responses": ["Lionel Messi is an Argentinian football legend.", "The FIFA World Cup is the biggest international football tournament.", "A football team has 11 players.", "Cristiano Ronaldo is a Portuguese football star.", "Modern football originated in England."]
    },
    {
      "tag": "maths_advanced",
      "patterns": ["What is integration?", "What is differentiation?", "Solve 2x+5=0", "What is matrix multiplication?", "What is probability?"],
      "responses": ["Integration is the process of finding the area under a curve.", "Differentiation finds the rate of change of a function.", "The solution is x = -2.5.", "Matrix multiplication combines rows and columns of two matrices.", "Probability is the measure of how likely an event is to occur."]
    },
    {
      "tag": "health_fitness",
      "patterns": ["How to lose weight?", "What are healthy foods?", "How much water should I drink?", "What is BMI?", "How to stay fit?"],
      "responses": ["Weight loss requires exercise and a balanced diet.", "Healthy foods include fruits, vegetables, and whole grains.", "An average adult should drink about 2–3 liters of water daily.", "BMI stands for Body Mass Index, a measure of body fat.", "Staying fit requires regular exercise, sleep, and a healthy diet."]
    },
    {
      "tag": "mental_health",
      "patterns": ["What is stress?", "How to deal with anxiety?", "What is depression?", "How to stay positive?", "What is mindfulness?"],
      "responses": ["Stress is the body's reaction to any demand or challenge.", "Anxiety can be managed with breathing exercises and mindfulness.", "Depression is a mental health condition causing sadness and loss of interest.", "Staying positive requires gratitude and focusing on good things.", "Mindfulness is being aware and present in the current moment."]
    },
    {
      "tag": "calculator",
      "patterns": ["Can you calculate?", "I need a calculator", "Do math for me", "Solve 123+456", "What is 500*3?"],
      "responses": ["123+456=579", "500×3=1500", "I work like a calculator!", "Just ask me any math problem.", "Sure, I’ll calculate that for you!"]
    }
]
}

# %% [markdown]
# lists for storing data

# %%
training_sentences = []
training_labels = []
labels = []
responses = []


for intent in data['intents']:
    for pattern in intent['patterns']:
        training_sentences.append(pattern)
        training_labels.append(intent['tag'])
    responses.append(intent['responses'])

    if intent['tag'] not in labels:
        labels.append(intent['tag'])

num_classes = len(labels)

# %% [markdown]
# Required Modules

# %%
import json
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# Label Encoding

# %%
lbl_encoder = LabelEncoder()
lbl_encoder.fit(training_labels)
training_labels = lbl_encoder.transform(training_labels)

# %% [markdown]
# Tokenization

# %%
vocab_size = 1000
embedding_dim = 16
max_len = 20
oov_token = "<OOV>"

tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_token)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_sentences)
padded_sequences = pad_sequences(sequences, truncating='post', maxlen=max_len)

# %% [markdown]
# MODEL Building

# %%
model = Sequential()
model.add(Embedding(vocab_size, embedding_dim, input_length=max_len))
model.add(GlobalAveragePooling1D())
model.add(Dense(16, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam', metrics=['accuracy'])

model.summary()
epochs = 500
history = model.fit(padded_sequences, np.array(training_labels), epochs=epochs)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_1      │ ?                      │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 165ms/step - accuracy: 0.0067 - loss: 3.7616
# Epoch 2/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.0228 - loss: 3.7602
# Epoch 3/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0466 - loss: 3.7587
# Epoch 4/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0444 - loss: 3.7578
# Epoch 5/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0561 - loss: 3.7564
# Epoch 6/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0489 - loss: 3.7569
# Epoch 7/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0353 - loss: 3.7565
# Epoch 8/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0536 - loss: 3.7487
# Epoch 9/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0330 - loss: 3.7508
# Epoch 10/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0402 - loss: 3.7501
# Epoch 11/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0572 - loss: 3.7444
# Epoch 12/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0455 - loss: 3.7423
# Epoch 13/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0481 - loss: 3.7424
# Epoch 14/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0533 - loss: 3.7363
# Epoch 15/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0637 - loss: 3.7312
# Epoch 16/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0487 - loss: 3.7409
# Epoch 17/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0287 - loss: 3.7378
# Epoch 18/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0563 - loss: 3.7356
# Epoch 19/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0447 - loss: 3.7426
# Epoch 20/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0479 - loss: 3.7259
# Epoch 21/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0368 - loss: 3.7378
# Epoch 22/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0560 - loss: 3.7301
# Epoch 23/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0485 - loss: 3.7168
# Epoch 24/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0496 - loss: 3.7268
# Epoch 25/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0514 - loss: 3.7212
# Epoch 26/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0439 - loss: 3.7143
# Epoch 27/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0438 - loss: 3.7196
# Epoch 28/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0660 - loss: 3.6930
# Epoch 29/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0639 - loss: 3.6932
# Epoch 30/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0470 - loss: 3.7125
# Epoch 31/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0334 - loss: 3.7109
# Epoch 32/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0629 - loss: 3.6905
# Epoch 33/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0259 - loss: 3.7140
# Epoch 34/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0407 - loss: 3.6909
# Epoch 35/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0448 - loss: 3.6844
# Epoch 36/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0422 - loss: 3.6832
# Epoch 37/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0642 - loss: 3.6632
# Epoch 38/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0660 - loss: 3.6531
# Epoch 39/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0479 - loss: 3.6544
# Epoch 40/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0481 - loss: 3.6494
# Epoch 41/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0465 - loss: 3.6398
# Epoch 42/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0659 - loss: 3.6071
# Epoch 43/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0421 - loss: 3.6373
# Epoch 44/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0397 - loss: 3.6117
# Epoch 45/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0470 - loss: 3.5733
# Epoch 46/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0463 - loss: 3.5649
# Epoch 47/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0431 - loss: 3.5339
# Epoch 48/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0608 - loss: 3.5127
# Epoch 49/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0649 - loss: 3.5063
# Epoch 50/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0790 - loss: 3.4721
# Epoch 51/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0925 - loss: 3.4318
# Epoch 52/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1001 - loss: 3.4249
# Epoch 53/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1143 - loss: 3.3923
# Epoch 54/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0884 - loss: 3.3588
# Epoch 55/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1040 - loss: 3.3216
# Epoch 56/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1395 - loss: 3.3174
# Epoch 57/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1025 - loss: 3.2826
# Epoch 58/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1052 - loss: 3.2730
# Epoch 59/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1343 - loss: 3.2331
# Epoch 60/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1181 - loss: 3.1726
# Epoch 61/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1282 - loss: 3.1812
# Epoch 62/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1535 - loss: 3.0748
# Epoch 63/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1514 - loss: 3.0399
# Epoch 64/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1590 - loss: 3.0042
# Epoch 65/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1847 - loss: 2.9359
# Epoch 66/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1380 - loss: 2.9718
# Epoch 67/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1779 - loss: 2.9473
# Epoch 68/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1607 - loss: 2.9281
# Epoch 69/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2064 - loss: 2.8195
# Epoch 70/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1919 - loss: 2.8503
# Epoch 71/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1708 - loss: 2.8045
# Epoch 72/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2050 - loss: 2.7612
# Epoch 73/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2240 - loss: 2.7473
# Epoch 74/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2468 - loss: 2.6260
# Epoch 75/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2323 - loss: 2.7211
# Epoch 76/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2334 - loss: 2.6510
# Epoch 77/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3099 - loss: 2.6031
# Epoch 78/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3049 - loss: 2.5538
# Epoch 79/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2489 - loss: 2.5612
# Epoch 80/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3007 - loss: 2.5184
# Epoch 81/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3763 - loss: 2.4120
# Epoch 82/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3834 - loss: 2.4113
# Epoch 83/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4031 - loss: 2.4004
# Epoch 84/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4309 - loss: 2.3744
# Epoch 85/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4156 - loss: 2.3909
# Epoch 86/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4262 - loss: 2.3551
# Epoch 87/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4853 - loss: 2.2757
# Epoch 88/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4102 - loss: 2.3143
# Epoch 89/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4879 - loss: 2.2548
# Epoch 90/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4815 - loss: 2.1986
# Epoch 91/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4543 - loss: 2.1848
# Epoch 92/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4850 - loss: 2.1684
# Epoch 93/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4873 - loss: 2.1742
# Epoch 94/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5616 - loss: 2.1034
# Epoch 95/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5197 - loss: 2.1092
# Epoch 96/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5373 - loss: 2.0810
# Epoch 97/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5434 - loss: 2.0200
# Epoch 98/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5380 - loss: 2.0201
# Epoch 99/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5774 - loss: 2.0048
# Epoch 100/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5468 - loss: 1.9887
# Epoch 101/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5562 - loss: 1.9246
# Epoch 102/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6051 - loss: 1.9297
# Epoch 103/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5912 - loss: 1.9002
# Epoch 104/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5616 - loss: 1.9487
# Epoch 105/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6092 - loss: 1.8976
# Epoch 106/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5618 - loss: 1.8966
# Epoch 107/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6117 - loss: 1.7679
# Epoch 108/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5523 - loss: 1.8777
# Epoch 109/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6095 - loss: 1.8088
# Epoch 110/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6381 - loss: 1.7819
# Epoch 111/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6268 - loss: 1.7519
# Epoch 112/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6470 - loss: 1.7356
# Epoch 113/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6397 - loss: 1.7164
# Epoch 114/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6468 - loss: 1.6956
# Epoch 115/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6525 - loss: 1.7234
# Epoch 116/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6594 - loss: 1.6831
# Epoch 117/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6531 - loss: 1.6711
# Epoch 118/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6883 - loss: 1.6032
# Epoch 119/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6895 - loss: 1.6434
# Epoch 120/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6963 - loss: 1.5700
# Epoch 121/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6515 - loss: 1.6475
# Epoch 122/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7448 - loss: 1.5492
# Epoch 123/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7271 - loss: 1.5080
# Epoch 124/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6688 - loss: 1.5539
# Epoch 125/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6675 - loss: 1.5945
# Epoch 126/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7479 - loss: 1.4626
# Epoch 127/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7198 - loss: 1.4747
# Epoch 128/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7280 - loss: 1.4819
# Epoch 129/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7557 - loss: 1.4034
# Epoch 130/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7389 - loss: 1.4490
# Epoch 131/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7706 - loss: 1.4223
# Epoch 132/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7674 - loss: 1.3378
# Epoch 133/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7251 - loss: 1.3854
# Epoch 134/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7838 - loss: 1.3982
# Epoch 135/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7803 - loss: 1.4192
# Epoch 136/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7879 - loss: 1.3150
# Epoch 137/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7892 - loss: 1.2748
# Epoch 138/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8065 - loss: 1.3063
# Epoch 139/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8002 - loss: 1.2737
# Epoch 140/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7916 - loss: 1.2738
# Epoch 141/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7683 - loss: 1.2972
# Epoch 142/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7637 - loss: 1.2854
# Epoch 143/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7610 - loss: 1.2302
# Epoch 144/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7560 - loss: 1.2793
# Epoch 145/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8331 - loss: 1.1756
# Epoch 146/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7698 - loss: 1.2763
# Epoch 147/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7922 - loss: 1.2105
# Epoch 148/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7853 - loss: 1.2031
# Epoch 149/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7970 - loss: 1.1807
# Epoch 150/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8020 - loss: 1.1374
# Epoch 151/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8133 - loss: 1.1210
# Epoch 152/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8361 - loss: 1.1312
# Epoch 153/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8092 - loss: 1.1449
# Epoch 154/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8161 - loss: 1.1626
# Epoch 155/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8433 - loss: 1.0985
# Epoch 156/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8223 - loss: 1.1041
# Epoch 157/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8394 - loss: 1.0744
# Epoch 158/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8271 - loss: 1.1220
# Epoch 159/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8474 - loss: 1.0381
# Epoch 160/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8433 - loss: 1.0380
# Epoch 161/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8447 - loss: 1.0234
# Epoch 162/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8632 - loss: 1.0080
# Epoch 163/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8039 - loss: 1.0659
# Epoch 164/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8288 - loss: 0.9673
# Epoch 165/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8104 - loss: 1.0407
# Epoch 166/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8178 - loss: 1.0301
# Epoch 167/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8448 - loss: 0.9612
# Epoch 168/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8267 - loss: 1.0084
# Epoch 169/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8309 - loss: 0.9937
# Epoch 170/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8405 - loss: 0.8836
# Epoch 171/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8078 - loss: 0.9937
# Epoch 172/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8174 - loss: 0.9632
# Epoch 173/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8334 - loss: 0.9588
# Epoch 174/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8770 - loss: 0.9152
# Epoch 175/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8349 - loss: 0.9644
# Epoch 176/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8644 - loss: 0.8750
# Epoch 177/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8666 - loss: 0.9031
# Epoch 178/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8502 - loss: 0.8793
# Epoch 179/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8758 - loss: 0.8330
# Epoch 180/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8543 - loss: 0.8517
# Epoch 181/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8658 - loss: 0.8418
# Epoch 182/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8510 - loss: 0.8713
# Epoch 183/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8734 - loss: 0.8047
# Epoch 184/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8868 - loss: 0.7855
# Epoch 185/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8776 - loss: 0.8019
# Epoch 186/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8493 - loss: 0.8502
# Epoch 187/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8637 - loss: 0.8296
# Epoch 188/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8811 - loss: 0.8313
# Epoch 189/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8735 - loss: 0.8376
# Epoch 190/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8654 - loss: 0.7601
# Epoch 191/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8881 - loss: 0.7580
# Epoch 192/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8715 - loss: 0.7831
# Epoch 193/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8646 - loss: 0.7881
# Epoch 194/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9065 - loss: 0.7546
# Epoch 195/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8975 - loss: 0.7696
# Epoch 196/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8684 - loss: 0.7270
# Epoch 197/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8871 - loss: 0.7209
# Epoch 198/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8642 - loss: 0.7377
# Epoch 199/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8822 - loss: 0.7138
# Epoch 200/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8863 - loss: 0.6935
# Epoch 201/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9135 - loss: 0.6748
# Epoch 202/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8690 - loss: 0.6915
# Epoch 203/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8742 - loss: 0.6927
# Epoch 204/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8944 - loss: 0.6830
# Epoch 205/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8844 - loss: 0.6781
# Epoch 206/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8977 - loss: 0.6836
# Epoch 207/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8694 - loss: 0.6630
# Epoch 208/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8899 - loss: 0.6733
# Epoch 209/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8905 - loss: 0.6528
# Epoch 210/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9137 - loss: 0.6191
# Epoch 211/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8940 - loss: 0.6607
# Epoch 212/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8869 - loss: 0.6299
# Epoch 213/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8927 - loss: 0.6317
# Epoch 214/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8976 - loss: 0.6098
# Epoch 215/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8960 - loss: 0.6215
# Epoch 216/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8730 - loss: 0.6220
# Epoch 217/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8939 - loss: 0.6271
# Epoch 218/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9190 - loss: 0.5984
# Epoch 219/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9010 - loss: 0.6131
# Epoch 220/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9154 - loss: 0.5668
# Epoch 221/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9125 - loss: 0.5778
# Epoch 222/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9171 - loss: 0.5858
# Epoch 223/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9320 - loss: 0.5401
# Epoch 224/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9483 - loss: 0.5450
# Epoch 225/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9040 - loss: 0.5466
# Epoch 226/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8977 - loss: 0.5915
# Epoch 227/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9100 - loss: 0.5438
# Epoch 228/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9096 - loss: 0.5503
# Epoch 229/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9099 - loss: 0.5417
# Epoch 230/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8757 - loss: 0.5761
# Epoch 231/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9149 - loss: 0.5200
# Epoch 232/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8923 - loss: 0.5203
# Epoch 233/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9182 - loss: 0.5061
# Epoch 234/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9284 - loss: 0.4740
# Epoch 235/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9026 - loss: 0.5197
# Epoch 236/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9239 - loss: 0.4893
# Epoch 237/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9386 - loss: 0.4635
# Epoch 238/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9072 - loss: 0.5005
# Epoch 239/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9237 - loss: 0.4759
# Epoch 240/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9327 - loss: 0.4626
# Epoch 241/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9360 - loss: 0.4625
# Epoch 242/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9109 - loss: 0.4892
# Epoch 243/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9147 - loss: 0.4957
# Epoch 244/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9323 - loss: 0.4378
# Epoch 245/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9316 - loss: 0.4383
# Epoch 246/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9407 - loss: 0.4535
# Epoch 247/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9216 - loss: 0.4202
# Epoch 248/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9395 - loss: 0.4246
# Epoch 249/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9205 - loss: 0.4468
# Epoch 250/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9586 - loss: 0.4256
# Epoch 251/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9341 - loss: 0.4293
# Epoch 252/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9243 - loss: 0.4135
# Epoch 253/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9388 - loss: 0.4092
# Epoch 254/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9360 - loss: 0.4190
# Epoch 255/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8946 - loss: 0.4280
# Epoch 256/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9426 - loss: 0.4248
# Epoch 257/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9260 - loss: 0.3888
# Epoch 258/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9476 - loss: 0.3976
# Epoch 259/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9375 - loss: 0.4138
# Epoch 260/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9376 - loss: 0.3778
# Epoch 261/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9600 - loss: 0.3800
# Epoch 262/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9367 - loss: 0.4122
# Epoch 263/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9405 - loss: 0.3677
# Epoch 264/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9464 - loss: 0.3709
# Epoch 265/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9644 - loss: 0.3475
# Epoch 266/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9597 - loss: 0.3566
# Epoch 267/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9664 - loss: 0.3376
# Epoch 268/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9590 - loss: 0.3503
# Epoch 269/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9581 - loss: 0.3371
# Epoch 270/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9336 - loss: 0.3962
# Epoch 271/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9542 - loss: 0.3564
# Epoch 272/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9634 - loss: 0.3204
# Epoch 273/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9636 - loss: 0.3557
# Epoch 274/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9548 - loss: 0.3311
# Epoch 275/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9504 - loss: 0.3300
# Epoch 276/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9523 - loss: 0.3054
# Epoch 277/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9657 - loss: 0.3056
# Epoch 278/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9735 - loss: 0.3238
# Epoch 279/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9568 - loss: 0.3222
# Epoch 280/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9568 - loss: 0.3149
# Epoch 281/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9697 - loss: 0.3040
# Epoch 282/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9553 - loss: 0.3220
# Epoch 283/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9642 - loss: 0.3109
# Epoch 284/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9625 - loss: 0.3065
# Epoch 285/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9791 - loss: 0.2633
# Epoch 286/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9668 - loss: 0.2977
# Epoch 287/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9667 - loss: 0.2943
# Epoch 288/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9593 - loss: 0.2921
# Epoch 289/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9575 - loss: 0.2728
# Epoch 290/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9811 - loss: 0.2887
# Epoch 291/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9565 - loss: 0.2768
# Epoch 292/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9703 - loss: 0.2550
# Epoch 293/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9524 - loss: 0.2878
# Epoch 294/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9560 - loss: 0.2824
# Epoch 295/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9673 - loss: 0.2495
# Epoch 296/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9801 - loss: 0.2467
# Epoch 297/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9598 - loss: 0.2756
# Epoch 298/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9717 - loss: 0.2623
# Epoch 299/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9749 - loss: 0.2366
# Epoch 300/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9690 - loss: 0.2536
# Epoch 301/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9673 - loss: 0.2590
# Epoch 302/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9876 - loss: 0.2556
# Epoch 303/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9739 - loss: 0.2320
# Epoch 304/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9663 - loss: 0.2575
# Epoch 305/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9857 - loss: 0.2112
# Epoch 306/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9851 - loss: 0.2113
# Epoch 307/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9734 - loss: 0.2315
# Epoch 308/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9769 - loss: 0.2389
# Epoch 309/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9865 - loss: 0.2308
# Epoch 310/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9852 - loss: 0.2037
# Epoch 311/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9819 - loss: 0.2130
# Epoch 312/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9711 - loss: 0.2113
# Epoch 313/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9828 - loss: 0.2070
# Epoch 314/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9742 - loss: 0.2090
# Epoch 315/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9838 - loss: 0.2074
# Epoch 316/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9720 - loss: 0.2136
# Epoch 317/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9914 - loss: 0.2034
# Epoch 318/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9811 - loss: 0.2019
# Epoch 319/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9829 - loss: 0.1974
# Epoch 320/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9680 - loss: 0.2015
# Epoch 321/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9778 - loss: 0.1933
# Epoch 322/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9768 - loss: 0.1941
# Epoch 323/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9737 - loss: 0.1992
# Epoch 324/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9759 - loss: 0.1972
# Epoch 325/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9906 - loss: 0.1785
# Epoch 326/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9869 - loss: 0.1852
# Epoch 327/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9728 - loss: 0.1908
# Epoch 328/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9870 - loss: 0.1838
# Epoch 329/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9837 - loss: 0.1939
# Epoch 330/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9762 - loss: 0.1977
# Epoch 331/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9797 - loss: 0.1903
# Epoch 332/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9901 - loss: 0.1605
# Epoch 333/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9951 - loss: 0.1593
# Epoch 334/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9640 - loss: 0.1990
# Epoch 335/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9927 - loss: 0.1654
# Epoch 336/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9816 - loss: 0.1754
# Epoch 337/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9936 - loss: 0.1712
# Epoch 338/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9722 - loss: 0.1857
# Epoch 339/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9855 - loss: 0.1624
# Epoch 340/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9850 - loss: 0.1732
# Epoch 341/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9769 - loss: 0.1827
# Epoch 342/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9830 - loss: 0.1562
# Epoch 343/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9906 - loss: 0.1494
# Epoch 344/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9877 - loss: 0.1524
# Epoch 345/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9883 - loss: 0.1570
# Epoch 346/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9686 - loss: 0.1632
# Epoch 347/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9888 - loss: 0.1503
# Epoch 348/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9919 - loss: 0.1444
# Epoch 349/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9933 - loss: 0.1609
# Epoch 350/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9920 - loss: 0.1358
# Epoch 351/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9895 - loss: 0.1455
# Epoch 352/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9912 - loss: 0.1362
# Epoch 353/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9914 - loss: 0.1410
# Epoch 354/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9924 - loss: 0.1476
# Epoch 355/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9818 - loss: 0.1465
# Epoch 356/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9893 - loss: 0.1417
# Epoch 357/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9915 - loss: 0.1512
# Epoch 358/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9888 - loss: 0.1342
# Epoch 359/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9805 - loss: 0.1412
# Epoch 360/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9932 - loss: 0.1321
# Epoch 361/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9856 - loss: 0.1538
# Epoch 362/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9797 - loss: 0.1650
# Epoch 363/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9955 - loss: 0.1412
# Epoch 364/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9874 - loss: 0.1212
# Epoch 365/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9882 - loss: 0.1331
# Epoch 366/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9817 - loss: 0.1375
# Epoch 367/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9878 - loss: 0.1326
# Epoch 368/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9896 - loss: 0.1246
# Epoch 369/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9928 - loss: 0.1134
# Epoch 370/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9874 - loss: 0.1386
# Epoch 371/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9937 - loss: 0.1242
# Epoch 372/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9905 - loss: 0.1238
# Epoch 373/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9856 - loss: 0.1287
# Epoch 374/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9945 - loss: 0.1187
# Epoch 375/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9883 - loss: 0.1139
# Epoch 376/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9920 - loss: 0.1088
# Epoch 377/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9854 - loss: 0.1286
# Epoch 378/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9927 - loss: 0.1121
# Epoch 379/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9988 - loss: 0.1074
# Epoch 380/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9843 - loss: 0.1293
# Epoch 381/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9945 - loss: 0.1056
# Epoch 382/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9932 - loss: 0.1042
# Epoch 383/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9924 - loss: 0.1117
# Epoch 384/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9924 - loss: 0.1072
# Epoch 385/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9915 - loss: 0.0999
# Epoch 386/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9824 - loss: 0.1147
# Epoch 387/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9943 - loss: 0.1012
# Epoch 388/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9856 - loss: 0.1181
# Epoch 389/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9933 - loss: 0.0977
# Epoch 390/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9866 - loss: 0.1074
# Epoch 391/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9924 - loss: 0.1049
# Epoch 392/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9874 - loss: 0.1070
# Epoch 393/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9955 - loss: 0.1034
# Epoch 394/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9895 - loss: 0.1028
# Epoch 395/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9856 - loss: 0.1012
# Epoch 396/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9915 - loss: 0.0922
# Epoch 397/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9947 - loss: 0.0886
# Epoch 398/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9856 - loss: 0.1010
# Epoch 399/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9895 - loss: 0.1018
# Epoch 400/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9866 - loss: 0.1010
# Epoch 401/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9886 - loss: 0.0975
# Epoch 402/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9905 - loss: 0.0938
# Epoch 403/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9924 - loss: 0.0980
# Epoch 404/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9784 - loss: 0.1068
# Epoch 405/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9843 - loss: 0.0970
# Epoch 406/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9969 - loss: 0.0871
# Epoch 407/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9945 - loss: 0.0844
# Epoch 408/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9882 - loss: 0.0902
# Epoch 409/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9882 - loss: 0.0950
# Epoch 410/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9905 - loss: 0.0929
# Epoch 411/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9913 - loss: 0.0864
# Epoch 412/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9843 - loss: 0.0859
# Epoch 413/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9905 - loss: 0.0819
# Epoch 414/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9882 - loss: 0.0878
# Epoch 415/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9901 - loss: 0.0908
# Epoch 416/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9805 - loss: 0.0922
# Epoch 417/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9924 - loss: 0.0750
# Epoch 418/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9962 - loss: 0.0818
# Epoch 419/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9945 - loss: 0.0784
# Epoch 420/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9931 - loss: 0.0862
# Epoch 421/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9955 - loss: 0.0732
# Epoch 422/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9969 - loss: 0.0731
# Epoch 423/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9866 - loss: 0.0790
# Epoch 424/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9758 - loss: 0.0941
# Epoch 425/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9939 - loss: 0.0797
# Epoch 426/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9940 - loss: 0.0769
# Epoch 427/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9945 - loss: 0.0690
# Epoch 428/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9945 - loss: 0.0754
# Epoch 429/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9932 - loss: 0.0659
# Epoch 430/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9932 - loss: 0.0778
# Epoch 431/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9913 - loss: 0.0762
# Epoch 432/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9767 - loss: 0.0781
# Epoch 433/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9945 - loss: 0.0727
# Epoch 434/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9837 - loss: 0.0706
# Epoch 435/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9893 - loss: 0.0707
# Epoch 436/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9843 - loss: 0.0774
# Epoch 437/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9906 - loss: 0.0572
# Epoch 438/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9902 - loss: 0.0682
# Epoch 439/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9939 - loss: 0.0594
# Epoch 440/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9794 - loss: 0.0776
# Epoch 441/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9931 - loss: 0.0699
# Epoch 442/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9847 - loss: 0.0709
# Epoch 443/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9955 - loss: 0.0619
# Epoch 444/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9854 - loss: 0.0713
# Epoch 445/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9844 - loss: 0.0715
# Epoch 446/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9864 - loss: 0.0679
# Epoch 447/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9933 - loss: 0.0560
# Epoch 448/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9924 - loss: 0.0646
# Epoch 449/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9937 - loss: 0.0637
# Epoch 450/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9963 - loss: 0.0556
# Epoch 451/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9963 - loss: 0.0686
# Epoch 452/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9824 - loss: 0.0648
# Epoch 453/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9945 - loss: 0.0601
# Epoch 454/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9877 - loss: 0.0639
# Epoch 455/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9943 - loss: 0.0512
# Epoch 456/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9863 - loss: 0.0607
# Epoch 457/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9945 - loss: 0.0607
# Epoch 458/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9856 - loss: 0.0662
# Epoch 459/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9817 - loss: 0.0621
# Epoch 460/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9924 - loss: 0.0537
# Epoch 461/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9913 - loss: 0.0624
# Epoch 462/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9913 - loss: 0.0497
# Epoch 463/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9896 - loss: 0.0559
# Epoch 464/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9894 - loss: 0.0573
# Epoch 465/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9937 - loss: 0.0472
# Epoch 466/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9955 - loss: 0.0516
# Epoch 467/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9901 - loss: 0.0605
# Epoch 468/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9787 - loss: 0.0648
# Epoch 469/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9797 - loss: 0.0683
# Epoch 470/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9915 - loss: 0.0472
# Epoch 471/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9952 - loss: 0.0502
# Epoch 472/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9824 - loss: 0.0588
# Epoch 473/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9939 - loss: 0.0529
# Epoch 474/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9928 - loss: 0.0518
# Epoch 475/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9883 - loss: 0.0518
# Epoch 476/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9882 - loss: 0.0682
# Epoch 477/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9915 - loss: 0.0535
# Epoch 478/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9847 - loss: 0.0521
# Epoch 479/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9962 - loss: 0.0445
# Epoch 480/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9924 - loss: 0.0571
# Epoch 481/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9932 - loss: 0.0561
# Epoch 482/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9937 - loss: 0.0496
# Epoch 483/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9883 - loss: 0.0514
# Epoch 484/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9955 - loss: 0.0434
# Epoch 485/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9883 - loss: 0.0481
# Epoch 486/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9859 - loss: 0.0476
# Epoch 487/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9830 - loss: 0.0523
# Epoch 488/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9915 - loss: 0.0537
# Epoch 489/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9895 - loss: 0.0527
# Epoch 490/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9924 - loss: 0.0455
# Epoch 491/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9846 - loss: 0.0487
# Epoch 492/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9945 - loss: 0.0418
# Epoch 493/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9859 - loss: 0.0510
# Epoch 494/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9854 - loss: 0.0450
# Epoch 495/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9951 - loss: 0.0536
# Epoch 496/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9945 - loss: 0.0464
# Epoch 497/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9945 - loss: 0.0395
# Epoch 498/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9928 - loss: 0.0476
# Epoch 499/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9854 - loss: 0.0533
# Epoch 500/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9877 - loss: 0.0429

# %% [markdown]
# Model save

# %%
model.save("chat_model.h5")

import pickle

# to save the fitted tokenizer
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# to save the fitted label encoder
with open('label_encoder.pickle', 'wb') as ecn_file:
    pickle.dump(lbl_encoder, ecn_file, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# CHATBOT

# %%
import json
import numpy as np
from tensorflow import keras
from sklearn.preprocessing import LabelEncoder

import random
import pickle

def chat():
    # load trained model
    model = keras.models.load_model('chat_model.h5')

    # load tokenizer object
    with open('tokenizer.pickle', 'rb') as handle:
        tokenizer = pickle.load(handle)

    # load label encoder object
    with open('label_encoder.pickle', 'rb') as enc:
        lbl_encoder = pickle.load(enc)

    # parameters
    max_len = 20

    while True:
        print("User: ", end="")
        inp = input()
        if inp.lower() == "quit":
            break

        result = model.predict(keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences([inp]),
                                             truncating='post', maxlen=max_len))
        tag = lbl_encoder.inverse_transform([np.argmax(result)])[0]

        for i in data['intents']:
            if i['tag'] == tag:
                print("ChatBot: " , np.random.choice(i['responses']))

print("Start messaging with the bot (type quit to stop)!")
chat()
# Out:
# Start messaging with the bot (type quit to stop)!
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# User: hi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# ChatBot:  Hello
# User: how are you
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# ChatBot:  I'm Joana, an Artificial Intelligent bot
# User: what you can dp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ChatBot:  I'm here to talk and keep you company!
# User: ok
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# ChatBot:  Hello
# User: i m sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# ChatBot:  Differentiation finds the rate of change of a function.
# User: what
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# ChatBot:  Bye! Come back again
# User: waht
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# ChatBot:  Hello
# User: hi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ChatBot:  Hi there
# User: what can u do
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# ChatBot:  I can chat with you, answer questions, and make you smile 😄
# User: ooo
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ChatBot:  Hi there
# User: tell me somthing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# ChatBot:  USA is a powerful country with many states.
# User: a joke
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ChatBot:  I told my computer a joke… but it didn’t get it 🤖
# User: ahahah vey funny
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ChatBot:  USA is a powerful country with many states.
# User: funny
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ChatBot:  USA is a powerful country with many states.
# User: okk dont say again
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# ChatBot:  Why was the math book sad? Because it had too many problems!
# User: over
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# ChatBot:  Samosa is a popular snack in India.
# User: by
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# ChatBot:  Tell me how can assist you
# User: good by
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ChatBot:  You can achieve anything!
# ChatBot:  Don’t give up!
# User: what is an over
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# ChatBot:  India won the 2011 Cricket World Cup.
# User: india
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# ChatBot:  USA is a powerful country with many states.
# User: inda
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# ChatBot:  Hi there
# User: inida
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ChatBot:  Hi there
# User: hi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ChatBot:  Hello
# User: gg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ChatBot:  Hello
# User: recommend me some movie
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# ChatBot:  You should watch Inception.
# User: is it good
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# ChatBot:  Check your device calendar for today’s date.
# User: quit
